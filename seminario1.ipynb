# %% [markdown]
# <a href="https://colab.research.google.com/github/Gutavo2000/LCE0212---Estat-stica-Aplicada-s-Ci-ncias-dos-Alimentos/blob/main/seminario1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
file_path = '/content/winequality-white.csv'
df = pd.read_csv(file_path, sep=';')

# Display the first 5 rows to understand the data structure
print("First 5 rows of the dataset:")
display(df.head())

print("\nInformation about the dataset:")
df.info()
# Out:
# First 5 rows of the dataset:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# ...

# %% [markdown]
# ### 1. Distribuição das notas de qualidade — gráfico de barras

# %%
# Count the occurrences of each quality score
quality_counts = df['quality'].value_counts().sort_index()

plt.figure(figsize=(10, 6))
sns.barplot(x=quality_counts.index, y=quality_counts.values, palette='viridis')
plt.title('Distribuição das Notas de Qualidade')
plt.xlabel('Qualidade')
plt.ylabel('Contagem')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# /tmp/ipykernel_1010/2384418428.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=quality_counts.index, y=quality_counts.values, palette='viridis')

# %% [markdown]
# ### 2. Histograma do teor alcoólico
#
# Eixo X: álcool (%)
# Eixo Y: frequência

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['alcohol'], kde=True, bins=20, color='skyblue')
plt.title('Histograma do Teor Alcoólico')
plt.xlabel('Álcool (%)')
plt.ylabel('Frequência')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ### 3. Boxplot do álcool por categoria de qualidade
#
# Vamos criar três categorias:
#
# *   **Baixa**: qualidade 3–5
# *   **Média**: qualidade 6
# *   **Alta**: qualidade 7–9

# %%
# Create quality categories
def categorize_quality(quality):
    if 3 <= quality <= 5:
        return 'Baixa'
    elif quality == 6:
        return 'Média'
    elif 7 <= quality <= 9:
        return 'Alta'
    return 'Outra'

df['quality_category'] = df['quality'].apply(categorize_quality)

# Ensure the order of categories in the plot
quality_order = ['Baixa', 'Média', 'Alta']
df['quality_category'] = pd.Categorical(df['quality_category'], categories=quality_order, ordered=True)

plt.figure(figsize=(10, 6))
sns.boxplot(x='quality_category', y='alcohol', data=df, palette='pastel')
plt.title('Teor Alcoólico por Categoria de Qualidade')
plt.xlabel('Categoria de Qualidade')
plt.ylabel('Álcool (%)')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# /tmp/ipykernel_1010/1974602578.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='quality_category', y='alcohol', data=df, palette='pastel')

# %% [markdown]
# ### 5. Dispersão: pH × acidez fixa
#
# Eixo X: pH
# Eixo Y: acidez fixa
#
# Cada ponto representa um vinho. Adicionaremos uma linha de tendência.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset (if not already loaded)
# This assumes the file path is the same as the initial loading cell
file_path = '/content/winequality-white.csv'
df = pd.read_csv(file_path, sep=';')

plt.figure(figsize=(10, 6))
sns.regplot(x='pH', y='fixed acidity', data=df, scatter_kws={'alpha':0.3}, line_kws={'color':'red'})
plt.title('Dispersão: pH vs. Acidez Fixa com Linha de Tendência')
plt.xlabel('pH')
plt.ylabel('Acidez Fixa')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

# Ensure df_combined is defined
if 'df_combined' not in locals() and 'df_combined' not in globals():
    # Ensure df (white wine) has the 'type' column
    if 'df' not in locals() or 'df' not in globals():
        # Re-load df if necessary (assuming white wine file exists or is handled by previous fix)
        white_wine_file_path = '/content/winequality-white.csv'
        if not os.path.exists(white_wine_file_path):
             print(f"Downloading {white_wine_file_path}...")
             # !wget -O {white_wine_file_path} https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv
        df = pd.read_csv(white_wine_file_path, sep=';')
    if 'type' not in df.columns:
        df['type'] = 'white'

    # Load red wine data
    red_wine_file_path = '/content/winequality-red.csv'
    if not os.path.exists(red_wine_file_path):
        print(f"Downloading {red_wine_file_path}...")
        # !wget -O {red_wine_file_path} https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv

    df_red = pd.read_csv(red_wine_file_path, sep=';')
    df_red['type'] = 'red'

    # Combine the two dataframes
    df_combined = pd.concat([df, df_red], ignore_index=True)

df_white_only = df_combined[df_combined['type'] == 'white']

plt.figure(figsize=(10, 6))
sns.regplot(x='residual sugar', y='density', data=df_white_only, scatter_kws={'alpha':0.3}, line_kws={'color':'blue'})
plt.title('Dispersão: Açúcar Residual vs. Densidade (Vinho Branco)')
plt.xlabel('Açúcar Residual')
plt.ylabel('Densidade')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()
# Out:
# ...
# --2026-08-26 23:41:24--  https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘/content/winequality-red.csv’
#
# /content/winequalit     [ <=>                ]  82.23K  --.-KB/s    in 0.1s
#
# 2026-08-26 23:41:25 (844 KB/s) - ‘/content/winequality-red.csv’ saved [84199]

# %% [markdown]
# ### 9. Coeficiente de Correlação: Açúcar Residual vs. Densidade
#
# Vamos calcular o coeficiente de correlação de Pearson entre 'Açúcar Residual' e 'Densidade' para o conjunto de dados combinado, e também para cada tipo de vinho separadamente, para entender melhor a força e a direção da relação linear.

# %%
# Coeficiente de correlação para o dataset combinado
correlation_overall = df_combined['residual sugar'].corr(df_combined['density'])
print(f"Coeficiente de Correlação (Geral) entre Açúcar Residual e Densidade: {correlation_overall:.3f}")

# Coeficiente de correlação para vinhos brancos
df_white_filtered = df_combined[df_combined['type'] == 'white']
correlation_white = df_white_filtered['residual sugar'].corr(df_white_filtered['density'])
print(f"Coeficiente de Correlação (Vinho Branco) entre Açúcar Residual e Densidade: {correlation_white:.3f}")

# Coeficiente de correlação para vinhos tintos
df_red_filtered = df_combined[df_combined['type'] == 'red']
correlation_red = df_red_filtered['residual sugar'].corr(df_red_filtered['density'])
print(f"Coeficiente de Correlação (Vinho Tinto) entre Açúcar Residual e Densidade: {correlation_red:.3f}")
# Out:
# Coeficiente de Correlação (Geral) entre Açúcar Residual e Densidade: 0.553
# Coeficiente de Correlação (Vinho Branco) entre Açúcar Residual e Densidade: 0.839
# Coeficiente de Correlação (Vinho Tinto) entre Açúcar Residual e Densidade: 0.355

# %% [markdown]
# ### 10. Identificando as Variáveis com Maior Correlação Positiva
#
# Vamos calcular a matriz de correlação para todas as variáveis numéricas no `df_combined` para identificar quais pares de variáveis apresentam os coeficientes de correlação mais próximos de 1 (forte correlação positiva).

# %%
# Calcular a matriz de correlação para todas as variáveis numéricas
correlation_matrix = df_combined.corr(numeric_only=True)

# Filtrar apenas as correlações positivas (exceto a correlação de uma variável consigo mesma)
positive_correlations = correlation_matrix[correlation_matrix < 1].stack()
positive_correlations = positive_correlations[positive_correlations > 0]

# Ordenar as correlações em ordem decrescente
sorted_correlations = positive_correlations.sort_values(ascending=False)

print("Os 10 maiores coeficientes de correlação positiva (excluindo correlação com a própria variável) são:")
print(sorted_correlations.head(10))
# Out:
# Os 10 maiores coeficientes de correlação positiva (excluindo correlação com a própria variável) são:
# total sulfur dioxide  free sulfur dioxide     0.720934
# free sulfur dioxide   total sulfur dioxide    0.720934
# density               residual sugar          0.552517
# residual sugar        density                 0.552517
#                       total sulfur dioxide    0.495482
# total sulfur dioxide  residual sugar          0.495482
# density               fixed acidity           0.458910
# fixed acidity         density                 0.458910
# quality               alcohol                 0.444319
# alcohol               quality                 0.444319
# dtype: float64

# %% [markdown]
# ### 11. Análise Descritiva para Vinhos Brancos: Média, Mediana, Desvio Padrão, Mínimo e Máximo

# %%
# Filtrar o DataFrame para incluir apenas vinhos brancos
df_white = df_combined[df_combined['type'] == 'white']

# Calcular as estatísticas descritivas para todas as variáveis numéricas
descriptive_stats_white = df_white.describe().transpose()

print("Estatísticas Descritivas para Vinhos Brancos:")
display(descriptive_stats_white)

# %% [markdown]
# ### 12. Análise Descritiva para Todas as Variáveis (Vinhos Branco e Tinto)

# %%
import pandas as pd

# df_combined is already available from previous cells, no need to re-create or re-download

# Calcular as estatísticas descritivas para todas as variáveis numéricas do dataset combinado
descriptive_stats_overall = df_combined.describe().transpose()

# Traduzir os nomes das colunas para português
descriptive_stats_overall.rename(columns={
    'count': 'Contagem',
    'mean': 'Média',
    'std': 'Desvio Padrão',
    'min': 'Mínima',
    '25%': 'Q1 (25%)',
    '50%': 'Mediana',
    '75%': 'Q3 (75%)',
    'max': 'Máxima'
}, inplace=True)

print("Estatísticas Descritivas para todas as variáveis (Vinhos Branco e Tinto):")
display(descriptive_stats_overall)
# Out:
# Estatísticas Descritivas para todas as variáveis (Vinhos Branco e Tinto):
#                       Contagem       Média  Desvio Padrão   Mínima  Q1 (25%)  \
# fixed acidity           6497.0    7.215307       1.296434  3.80000   6.40000
# volatile acidity        6497.0    0.339666       0.164636  0.08000   0.23000
# citric acid             6497.0    0.318633       0.145318  0.00000   0.25000
# residual sugar          6497.0    5.443235       4.757804  0.60000   1.80000
# chlorides               6497.0    0.056034       0.035034  0.00900   0.03800
# free sulfur dioxide     6497.0   30.525319      17.749400  1.00000  17.00000
# total sulfur dioxide    6497.0  115.744574      56.521855  6.00000  77.00000
# density                 6497.0    0.994697       0.002999  0.98711   0.99234
# pH                      6497.0    3.218501       0.160787  2.72000   3.11000
# sulphates               6497.0    0.531268       0.148806  0.22000   0.43000
# ...

# %% [markdown]
# Referencia
# https://archive.ics.uci.edu/dataset/186/wine+quality

# %% [markdown]
# ### 13. Caracterização da Base de Dados

# %%
# Número de amostras
num_samples = df_combined.shape[0]

# Quantidade de variáveis
num_variables = df_combined.shape[1]

# Variáveis físico-químicas (todas exceto 'quality' e 'type')
physicochemical_vars = df_combined.drop(columns=['quality', 'type']).columns.tolist()
physicochemical_vars_str = ', '.join(physicochemical_vars)

# Variável de qualidade
quality_variable = 'quality'

# Intervalo de notas de qualidade
min_quality = df_combined['quality'].min()
max_quality = df_combined['quality'].max()
quality_range = f'{min_quality} - {max_quality}'

# Valores ausentes
missing_values_count = df_combined.isnull().sum().sum()
missing_values_presence = 'Sim' if missing_values_count > 0 else 'Não'

# Criar um DataFrame para o resumo
data_summary = pd.DataFrame({
    'Característica': [
        'Número de Amostras',
        'Quantidade de Variáveis',
        'Variáveis Físico-Químicas',
        'Variável de Qualidade',
        'Intervalo de Notas de Qualidade',
        'Valores Ausentes'
    ],
    'Valor': [
        num_samples,
        num_variables,
        physicochemical_vars_str,
        quality_variable,
        quality_range,
        f'{missing_values_presence} ({missing_values_count} total)'
    ]
})

print("Tabela de Caracterização da Base de Dados:")
display(data_summary)
# Out:
# Tabela de Caracterização da Base de Dados:
#                     Característica  \
# 0               Número de Amostras
# 1          Quantidade de Variáveis
# 2        Variáveis Físico-Químicas
# 3            Variável de Qualidade
# 4  Intervalo de Notas de Qualidade
# 5                 Valores Ausentes
#
#                                                Valor
# 0                                               6497
# 1                                                 13
# 2  fixed acidity, volatile acidity, citric acid, ...
# 3                                            quality
# 4                                              3 - 9
# 5                                      Não (0 total)

# %% [markdown]
# ### 15. Tabela de Correlações Específicas para Vinho Branco

# %%
import pandas as pd

# Filtrar o DataFrame para incluir apenas vinhos brancos
df_white_only = df_combined[df_combined['type'] == 'white']

# Calcular as correlações específicas para vinho branco
corr_residual_sugar_density_white = df_white_only['residual sugar'].corr(df_white_only['density'])
corr_density_alcohol_white = df_white_only['density'].corr(df_white_only['alcohol'])
corr_free_sulfur_total_sulfur_white = df_white_only['free sulfur dioxide'].corr(df_white_only['total sulfur dioxide'])
corr_ph_fixed_acidity_white = df_white_only['pH'].corr(df_white_only['fixed acidity'])
corr_alcohol_quality_white = df_white_only['alcohol'].corr(df_white_only['quality'])

# Criar um DataFrame para a tabela de correlações do vinho branco
correlation_table_white = pd.DataFrame({
    'Par de Variáveis': [
        'Açúcar Residual x Densidade',
        'Densidade x Álcool',
        'Dióxido de Enxofre Livre x Dióxido de Enxofre Total',
        'pH x Acidez Fixa',
        'Álcool x Qualidade'
    ],
    'Coeficiente de Correlação (Vinho Branco)': [
        corr_residual_sugar_density_white,
        corr_density_alcohol_white,
        corr_free_sulfur_total_sulfur_white,
        corr_ph_fixed_acidity_white,
        corr_alcohol_quality_white
    ]
})

print("Tabela de Correlações (Vinho Branco):")
display(correlation_table_white.round(3))
# Out:
# Tabela de Correlações (Vinho Branco):
#                                     Par de Variáveis  \
# 0                        Açúcar Residual x Densidade
# 1                                 Densidade x Álcool
# 2  Dióxido de Enxofre Livre x Dióxido de Enxofre ...
# 3                                   pH x Acidez Fixa
# 4                                 Álcool x Qualidade
#
#    Coeficiente de Correlação (Vinho Branco)
# 0                                     0.839
# 1                                    -0.780
# 2                                     0.616
# 3                                    -0.426
# 4                                     0.436
